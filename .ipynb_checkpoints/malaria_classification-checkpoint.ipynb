# %% [markdown]
# ## 1. Problem statement

# %% [markdown]
# Task: TensorFlow is an open-source machine learning framework developed by Google for the sole purpose of building and training machine learning models.
#
# One of the datasets under the Tensorflow Image libraries is a malaria dataset which contains approximately 27,500 cell images of parasitized and uninfected cells from thin blood smear slide images of segmented cells.
#
#  **Objective**
#
#  To create a model which is able to classify whether a blood smear is uninfected or parasitized.

# %% [markdown]
# ###  Classes

# %% [markdown]
# - parasitized
# - uninfected

# %% [markdown]
# ###  Import Libraries

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import classification_report, confusion_matrix 
warnings.filterwarnings("ignore")
# Out:
# 2024-05-12 20:16:42.388473: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-12 20:16:42.388559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-12 20:16:42.514238: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
#declaring predefined variables

IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %% [markdown]
# ###  Load Dataset

# %%
dataset, info = tfds.load("malaria",split="train",  batch_size=BATCH_SIZE, shuffle_files=True, with_info=True, as_supervised=True)

# %% [markdown]
# ##  2. Data Understanding

# %%
print("Numeber of classes: ", info.features["label"].num_classes)
print("Class Names: ", info.features["label"].names)
# Out:
# Numeber of classes:  2
# Class Names:  ['parasitized', 'uninfected']

# %%
# showing samples

plt.figure(figsize=(15,5))

for image, label in dataset.take(1):
    for i in range(8):
        plt.subplot(2,4,i+1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(info.features["label"].names[label[i].numpy()])
        plt.axis("off")

# %% [markdown]
# ##  3. Data Preproccessing and Feature Engineering

# %%
#we have a total of 862 batches of 32

len(dataset)
# Out:
# 862

# %%
#function to split data into train validation and test in the ratio of 80:10:10 respectively

def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %% [markdown]
# ### Normalization and Resizing

# %%
#we resize the images to be of size 256 by 256
#then, we normalize the features by dividing it by 255

def process_image(img,label):
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize_with_crop_or_pad(img,IMAGE_SIZE,IMAGE_SIZE)
    img = tf.reshape(img, (-1,IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
    label = tf.reshape(label, (-1,1))
    return img, label

# %%
train_ds = train_ds.map(process_image)
val_ds = val_ds.map(process_image)
test_ds = test_ds.map(process_image)

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### Model Architecture

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3),  activation='relu'))
model.add(MaxPooling2D()),
model.add(Conv2D(64, (3,3),  activation='relu'))
model.add(MaxPooling2D()),
model.add(Conv2D(64, (3,3),  activation='relu'))
model.add(MaxPooling2D()),
model.add(Conv2D(32, (3,3),  activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#summary of our model

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 152,801 (596.88 KB)
#  Trainable params: 152,801 (596.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ###  Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### Training

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(
      train_ds,
      batch_size=BATCH_SIZE,
      validation_data=val_ds,
      verbose=1,
      epochs=25,
    callbacks=[tensorboard_callback]
  )
# Out:
# Epoch 1/25
#   2/689 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.5469 - loss: 0.6929
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715526685.454144     127 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.7712 - loss: 0.4169 - val_accuracy: 0.9564 - val_loss: 0.1491
# Epoch 2/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9556 - loss: 0.1424 - val_accuracy: 0.9553 - val_loss: 0.1425
# Epoch 3/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 55s 66ms/step - accuracy: 0.9611 - loss: 0.1246 - val_accuracy: 0.9575 - val_loss: 0.1188
# Epoch 4/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9586 - loss: 0.1296 - val_accuracy: 0.9608 - val_loss: 0.1131
# Epoch 5/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9584 - loss: 0.1277 - val_accuracy: 0.9640 - val_loss: 0.0999
# Epoch 6/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 52s 63ms/step - accuracy: 0.9616 - loss: 0.1112 - val_accuracy: 0.9622 - val_loss: 0.1131
# Epoch 7/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9658 - loss: 0.1067 - val_accuracy: 0.9622 - val_loss: 0.1159
# Epoch 8/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9645 - loss: 0.1047 - val_accuracy: 0.9677 - val_loss: 0.0998
# Epoch 9/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 53s 64ms/step - accuracy: 0.9629 - loss: 0.1079 - val_accuracy: 0.9655 - val_loss: 0.0995
# Epoch 10/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 55s 66ms/step - accuracy: 0.9645 - loss: 0.0988 - val_accuracy: 0.9600 - val_loss: 0.1185
# Epoch 11/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 55s 67ms/step - accuracy: 0.9681 - loss: 0.0923 - val_accuracy: 0.9677 - val_loss: 0.0825
# Epoch 12/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9680 - loss: 0.0895 - val_accuracy: 0.9735 - val_loss: 0.0820
# Epoch 13/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9674 - loss: 0.0975 - val_accuracy: 0.9771 - val_loss: 0.0665
# Epoch 14/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 52s 63ms/step - accuracy: 0.9700 - loss: 0.0836 - val_accuracy: 0.9746 - val_loss: 0.0702
# Epoch 15/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 53s 65ms/step - accuracy: 0.9709 - loss: 0.0890 - val_accuracy: 0.9746 - val_loss: 0.0757
# Epoch 16/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 50s 63ms/step - accuracy: 0.9707 - loss: 0.0807 - val_accuracy: 0.9717 - val_loss: 0.0836
# Epoch 17/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 51s 63ms/step - accuracy: 0.9751 - loss: 0.0734 - val_accuracy: 0.9746 - val_loss: 0.0712
# Epoch 18/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9735 - loss: 0.0772 - val_accuracy: 0.9727 - val_loss: 0.0801
# Epoch 19/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 53s 66ms/step - accuracy: 0.9704 - loss: 0.0811 - val_accuracy: 0.9764 - val_loss: 0.0656
# Epoch 20/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 51s 64ms/step - accuracy: 0.9749 - loss: 0.0767 - val_accuracy: 0.9760 - val_loss: 0.0720
# Epoch 21/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9772 - loss: 0.0683 - val_accuracy: 0.9807 - val_loss: 0.0573
# Epoch 22/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9709 - loss: 0.0770 - val_accuracy: 0.9753 - val_loss: 0.0675
# Epoch 23/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9774 - loss: 0.0655 - val_accuracy: 0.9804 - val_loss: 0.0532
# Epoch 24/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 52s 63ms/step - accuracy: 0.9792 - loss: 0.0617 - val_accuracy: 0.9782 - val_loss: 0.0693
# Epoch 25/25
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 54s 66ms/step - accuracy: 0.9800 - loss: 0.0585 - val_accuracy: 0.9767 - val_loss: 0.0599

# %% [markdown]
# ### Plot Performance

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend(loc='upper right')
plt.title('Loss') 
 
   
plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'],  label='accuracy')
plt.plot(hist.history['val_accuracy'],  label='val_accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# ## 5. Testing

# %%
model.evaluate(test_ds)
# Out:
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9712 - loss: 0.0868
# [0.07537022233009338, 0.9757070541381836]

# %%
labels = []
batch_prediction = []

for images_batch, labels_batch in test_ds:
    for i in range(len(images_batch)):
        labels.append(labels_batch[i][0].numpy())
        batch_prediction.append(model.predict(images_batch))
        
preds = np.round(batch_prediction).reshape(-1)
labels = np.reshape(labels,-1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
print(confusion_matrix(label,preds))
print('\n')
print(classification_report(label,preds))
# Out:
# [[1329   37]
#  [  26 1392]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1366
#            1       0.97      0.98      0.98      1418
#
#     accuracy                           0.98      2784
#    macro avg       0.98      0.98      0.98      2784
# weighted avg       0.98      0.98      0.98      2784

# %% [markdown]
# ### Run Prediction on Sample

# %%
class_names = info.features["label"].names

# %%
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy()
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label[0]])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[round(batch_prediction[0][0])])
# Out:
# first image to predict
# actual label: uninfected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted label: uninfected

# %% [markdown]
# ## Saving the model

# %%
model.save("malaria.h5")
